# %%
import pandas as pd

# %%
df = pd.read_csv("WVS_Cross-National_Wave_7_csv_v6_0.csv")
# Out:
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\3779979485.py:1: DtypeWarning: Columns (346,348,350,580,581,582,583) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("WVS_Cross-National_Wave_7_csv_v6_0.csv")

# %%
df
# Out:
#                   version                        doi  A_WAVE  A_YEAR  A_STUDY  \
# 0      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 1      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 2      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 3      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 4      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# ...                   ...                        ...     ...     ...      ...
# 97215  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97216  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97217  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97218  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97219  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
#
#        B_COUNTRY B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  D_INTERVIEW  ...  \
# 0             20             AND        232         AND     20070001  ...
# 1             20             AND        232         AND     20070002  ...
# 2             20             AND        232         AND     20070003  ...
# 3             20             AND        232         AND     20070004  ...
# 4             20             AND        232         AND     20070005  ...
# ...          ...             ...        ...         ...          ...  ...
# 97215        716             ZWE        552         ZIM    716071211  ...
# 97216        716             ZWE        552         ZIM    716071212  ...
# 97217        716             ZWE        552         ZIM    716071213  ...
# 97218        716             ZWE        552         ZIM    716071214  ...
# 97219        716             ZWE        552         ZIM    716071215  ...
#
#        WVS_Polmistrust_PartyVoter  WVS_LR_MedianVoter  WVS_LibCon_MedianVoter  \
# 0                       62.434211              -999.0                  -999.0
# 1                       62.434211              -999.0                  -999.0
# 2                       62.434211              -999.0                  -999.0
# 3                             NaN                 NaN                     NaN
# 4                       66.964286              -999.0                  -999.0
# ...                           ...                 ...                     ...
# 97215                         NaN                 NaN                     NaN
# 97216                         NaN                 NaN                     NaN
# 97217                         NaN                 NaN                     NaN
# 97218                         NaN                 NaN                     NaN
# 97219                         NaN                 NaN                     NaN
#
#        v2psbars  v2psorgs  v2psprbrch  v2psprlnks  v2psplats  v2xnp_client  \
# 0        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# 1        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# 2        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# 3           NaN       NaN         NaN         NaN        NaN           NaN
# 4        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# ...         ...       ...         ...         ...        ...           ...
# 97215       NaN       NaN         NaN         NaN        NaN           NaN
# 97216       NaN       NaN         NaN         NaN        NaN           NaN
# 97217       NaN       NaN         NaN         NaN        NaN           NaN
# 97218       NaN       NaN         NaN         NaN        NaN           NaN
# 97219       NaN       NaN         NaN         NaN        NaN           NaN
#
#        v2xps_party
# 0           -999.0
# 1           -999.0
# 2           -999.0
# 3              NaN
# 4           -999.0
# ...            ...
# 97215          NaN
# 97216          NaN
# 97217          NaN
# 97218          NaN
# 97219          NaN
#
# [97220 rows x 613 columns]

# %%
df.describe()
# Out:
#         A_WAVE        A_YEAR  A_STUDY     B_COUNTRY     C_COW_NUM  \
# count  97220.0  97220.000000  97220.0  97220.000000  97220.000000
# mean       7.0   2019.132082      2.0    447.872146    476.555153
# std        0.0      1.601004      0.0    256.491312    288.386918
# min        7.0   2017.000000      2.0     20.000000      2.000000
# 25%        7.0   2018.000000      2.0    218.000000    201.000000
# 50%        7.0   2018.000000      2.0    422.000000    552.000000
# 75%        7.0   2020.000000      2.0    688.000000    714.000000
# max        7.0   2023.000000      2.0    909.000000    920.000000
#
#         D_INTERVIEW          S007     J_INTDATE       FW_START         FW_END  \
# count  9.722000e+04  9.722000e+04  9.722000e+04   97220.000000   97220.000000
# mean   4.479431e+08  4.485726e+08  1.905207e+07  201901.606881  201919.989683
# std    2.564912e+08  2.564602e+08  4.658281e+06     160.980181     160.412353
# min    2.007000e+07  2.072000e+07 -5.000000e+00  201701.000000  201703.000000
# 25%    2.180700e+08  2.187200e+08  2.018022e+07  201804.000000  201806.000000
# 50%    4.220707e+08  4.227207e+08  2.018111e+07  201811.000000  201812.000000
# 75%    6.880703e+08  6.887203e+08  2.020041e+07  202003.000000  202010.000000
# max    9.090704e+08  9.090704e+08  2.023070e+07  202306.000000  202307.000000
#
#        ...  WVS_Polmistrust_PartyVoter  WVS_LR_MedianVoter  \
# count  ...                 3918.000000         3918.000000
# mean   ...                   67.689823         -331.856360
# std    ...                    9.814691          474.786005
# min    ...                   43.750000         -999.000000
# 25%    ...                   66.964286         -999.000000
# 50%    ...                   68.210839            5.420000
# 75%    ...                   74.000000            5.650000
# max    ...                   83.705786            7.260000
#
#        WVS_LibCon_MedianVoter     v2psbars     v2psorgs   v2psprbrch  \
# count             3918.000000  3918.000000  3918.000000  3918.000000
# mean              -331.510837  -334.689260  -334.827539  -335.095391
# std                475.033906   472.769807   472.671155   472.481026
# min               -999.000000  -999.000000  -999.000000  -999.000000
# 25%               -999.000000  -999.000000  -999.000000  -999.000000
# 50%                  5.083400     0.552000     0.869000    -0.403000
# 75%                  6.512500     2.043000     1.737000     1.676000
# max                  9.402100     2.407000     1.737000     1.676000
#
#         v2psprlnks    v2psplats  v2xnp_client  v2xps_party
# count  3918.000000  3918.000000   3918.000000  3918.000000
# mean   -334.788026  -334.811147   -335.648640  -335.268652
# std     472.700209   472.683543    472.086732   472.357142
# min    -999.000000  -999.000000   -999.000000  -999.000000
# 25%    -999.000000  -999.000000   -999.000000  -999.000000
# 50%      -0.107000    -0.099000      0.059000     0.591000
# 75%       2.525000     2.354000      0.459000     0.927000
# max       2.525000     2.354000      0.624000     0.927000
#
# [8 rows x 601 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97220 entries, 0 to 97219
# Columns: 613 entries, version to v2xps_party
# dtypes: float64(195), int64(406), object(12)
# memory usage: 454.7+ MB

# %%
str(df.columns)
# Out:
# "Index(['version', 'doi', 'A_WAVE', 'A_YEAR', 'A_STUDY', 'B_COUNTRY',\n       'B_COUNTRY_ALPHA', 'C_COW_NUM', 'C_COW_ALPHA', 'D_INTERVIEW',\n       ...\n       'WVS_Polmistrust_PartyVoter', 'WVS_LR_MedianVoter',\n       'WVS_LibCon_MedianVoter', 'v2psbars', 'v2psorgs', 'v2psprbrch',\n       'v2psprlnks', 'v2psplats', 'v2xnp_client', 'v2xps_party'],\n      dtype='object', length=613)"

# %%
def count_nulls(df):
    for i in df.columns:
        print(i, df[i].isna().sum())

# %%
count_nulls(df)
# Out:
# version 0
# doi 0
# A_WAVE 0
# A_YEAR 0
# A_STUDY 0
# B_COUNTRY 0
# B_COUNTRY_ALPHA 0
# C_COW_NUM 0
# C_COW_ALPHA 0
# D_INTERVIEW 0
# S007 0
# J_INTDATE 0
# FW_START 0
# FW_END 0
# K_TIME_START 0
# K_TIME_END 0
# K_DURATION 0
# Q_MODE 0
# N_REGION_ISO 0
# N_REGION_WVS 0
# I_RELIGIMP 926
# I_RELIGBEL 2652
# I_RELIGPRAC 1212
# DISBELIEF 700
# I_NORM1 3539
# I_NORM2 1279
# I_NORM3 1194
# RELATIVISM 963
# I_TRUSTARMY 4323
# I_TRUSTPOLICE 2412
# I_TRUSTCOURTS 3511
# SCEPTICISM 2383
# I_INDEP 1038
# I_IMAGIN 1203
# I_NONOBED 1192
# AUTONOMY 1214
# I_WOMJOB 736
# I_WOMPOL 2641
# I_WOMEDU 1428
# EQUALITY 878
# I_HOMOLIB 7515
# I_ABORTLIB 2275
# I_DIVORLIB 1929
# CHOICE 1965
# I_VOICE1 3142
# I_VOICE2 4280
# I_VOI2_00 5379
# VOICE 2014
# SECVALWGT 0
# RESEMAVALWGT 0
# fhregion 447
# polregfh 447
# freestfh 447
# prfhrat 447
# prfhscore 447
# clfhrat 447
# clfhscore 447
# democ 447
# autoc 447
# polity 447
# durable 447
# regtype 447
# ruleoflaw 447
# corrupttransp 447
# electintegr 447
# btiregion 447
# btistatus 447
# btidemstatus 447
# btistate 447
# btipolpart 447
# btiruleoflaw 447
# btistability 447
# btiintegration 447
# btimarket 447
# btigovindex 447
# btigoveperform 447
# btiregime 447
# regionWB 447
# incomeWB 447
# landWB 447
# GDPpercap1 447
# GDPpercap2 447
# giniWB 447
# incrichest10p 447
# popWB1990 447
# popWB2000 447
# popWB2019 447
# lifeexpect 447
# popgrowth 447
# urbanpop 447
# laborforce 447
# deathrate 447
# unemployfem 447
# unemploymale 447
# unemploytotal 447
# accessclfuel 447
# accesselectr 447
# renewelectr 447
# co2emis 447
# co2percap 447
# easeofbusiness 447
# militaryexp 447
# Trade 447
# healthexp 447
# educationexp 447
# medageun 447
# meanschooling 447
# educationHDI 447
# compulseduc 447
# GII 447
# DGI 447
# womenparl 447
# hdi 447
# incomeindexHDI 447
# humanineqiality 447
# lifeexpectHDI 447
# homiciderate 447
# Refugeesorigin 447
# internetusers 447
# mobphone 447
# migrationrate 447
# schoolgpi 447
# femchoutsch 447
# choutsch 447
# v2x_polyarchy 447
# v2x_libdem 447
# v2x_partipdem 447
# v2x_delibdem 447
# v2x_egaldem 447
# v2x_freexp_altinf 447
# v2x_frassoc_thick 447
# v2xel_frefair 447
# v2xcl_rol 447
# v2x_cspart 447
# v2xeg_eqdr 447
# v2excrptps 447
# v2exthftps 447
# v2juaccnt 447
# v2cltrnslw 447
# v2clacjust 447
# v2clsocgrp 447
# v2clacfree 447
# v2clrelig 447
# v2csrlgrep 447
# v2mecenefm 447
# v2mecenefi 447
# v2mebias 447
# v2pepwrses 447
# v2pepwrgen 447
# v2peedueq 447
# v2pehealth 447
# v2peapsecon 447
# v2peasjsoecon 447
# v2clgencl 447
# v2peasjgen 447
# v2peasbgen 447
# v2cafres 1447
# v2cafexch 1447
# v2x_corr 447
# v2x_gender 447
# v2x_gencl 447
# v2x_genpp 447
# v2x_rule 447
# v2xcl_acjst 447
# td_voiacc 447
# td_polstab 447
# td_goveff 447
# td_regqual 447
# td_rulelaw 447
# td_ctrlcorr 447
# ID_GPS 93302
# ID_PartyFacts 93302
# Partyname 62412
# Partyabb 94619
# CPARTY 94619
# CPARTYABB 94619
# Type_Values 93302
# Type_Populism 93302
# Type_Populist_Values 93302
# Type_Partysize_vote 93302
# Type_Partysize_seat 93302
# GPS_V4_Scale 93302
# GPS_V6_Scale 93302
# GPS_V8_Scale 93302
# GPS_V9 93302
# GPS_V10 93302
# GPS_V11 93302
# GPS_V12 93302
# GPS_V13 93302
# GPS_V14 93302
# GPS_V15 93302
# GPS_V16 93302
# GPS_V17 93302
# WVS_LR_PartyVoter 93302
# WVS_LibCon_PartyVoter 93302
# WVS_Polmistrust_PartyVoter 93302
# WVS_LR_MedianVoter 93302
# WVS_LibCon_MedianVoter 93302
# v2psbars 93302
# v2psorgs 93302
# v2psprbrch 93302
# v2psprlnks 93302
# v2psplats 93302
# v2xnp_client 93302
# v2xps_party 93302

# %%
to_drop = []
for i in df.columns:
    if df[i].isna().sum()>90000:
        to_drop.append(i)
to_drop
# Out:
# ['ID_GPS',
#  'ID_PartyFacts',
#  'Partyabb',
#  'CPARTY',
#  'CPARTYABB',
#  'Type_Values',
#  'Type_Populism',
#  'Type_Populist_Values',
#  'Type_Partysize_vote',
#  'Type_Partysize_seat',
#  'GPS_V4_Scale',
#  'GPS_V6_Scale',
#  'GPS_V8_Scale',
#  'GPS_V9',
#  'GPS_V10',
#  'GPS_V11',
#  'GPS_V12',
#  'GPS_V13',
#  'GPS_V14',
#  'GPS_V15',
#  'GPS_V16',
#  'GPS_V17',
#  'WVS_LR_PartyVoter',
#  'WVS_LibCon_PartyVoter',
#  'WVS_Polmistrust_PartyVoter',
#  'WVS_LR_MedianVoter',
#  'WVS_LibCon_MedianVoter',
#  'v2psbars',
#  'v2psorgs',
#  'v2psprbrch',
#  'v2psprlnks',
#  'v2psplats',
#  'v2xnp_client',
#  'v2xps_party']

# %%
df_v1 = df.drop(columns=to_drop, axis=1)

# %%
count_nulls(df_v1)
# Out:
# version 0
# doi 0
# A_WAVE 0
# A_YEAR 0
# A_STUDY 0
# B_COUNTRY 0
# B_COUNTRY_ALPHA 0
# C_COW_NUM 0
# C_COW_ALPHA 0
# D_INTERVIEW 0
# S007 0
# J_INTDATE 0
# FW_START 0
# FW_END 0
# K_TIME_START 0
# K_TIME_END 0
# K_DURATION 0
# Q_MODE 0
# N_REGION_ISO 0
# N_REGION_WVS 0
# N_REGION_NUTS2 0
# N_REG_NUTS1 0
# N_TOWN 1
# G_TOWNSIZE 0
# G_TOWNSIZE2 0
# H_SETTLEMENT 0
# H_URBRURAL 0
# I_PSU 0
# O1_LONGITUDE 4
# O2_LATITUDE 4
# L_INTERVIEWER_NUMBER 0
# S_INTLANGUAGE 0
# LNGE_ISO 0
# E_RESPINT 0
# F_INTPRIVACY 0
# E1_LITERACY 0
# W_WEIGHT 0
# S018 0
# PWGHT 0
# S025 0
# Q1 0
# Q2 0
# Q3 0
# Q4 0
# Q5 0
# Q6 0
# Q7 0
# Q8 0
# Q9 0
# Q10 0
# Q11 0
# Q12 0
# Q13 0
# Q14 0
# Q15 0
# Q16 0
# Q17 0
# Q18 0
# Q19 0
# Q20 0
# Q21 0
# Q22 0
# Q23 0
# Q24 0
# Q25 0
# Q26 0
# Q27 0
# Q28 0
# Q29 0
# polity 447
# durable 447
# regtype 447
# ruleoflaw 447
# corrupttransp 447
# electintegr 447
# btiregion 447
# btistatus 447
# btidemstatus 447
# btistate 447
# btipolpart 447
# btiruleoflaw 447
# btistability 447
# btiintegration 447
# btimarket 447
# btigovindex 447
# btigoveperform 447
# btiregime 447
# regionWB 447
# incomeWB 447
# landWB 447
# GDPpercap1 447
# GDPpercap2 447
# giniWB 447
# incrichest10p 447
# popWB1990 447
# popWB2000 447
# popWB2019 447
# lifeexpect 447
# popgrowth 447
# urbanpop 447
# laborforce 447
# deathrate 447
# unemployfem 447
# unemploymale 447
# unemploytotal 447
# accessclfuel 447
# accesselectr 447
# renewelectr 447
# co2emis 447
# co2percap 447
# easeofbusiness 447
# militaryexp 447
# Trade 447
# healthexp 447
# educationexp 447
# medageun 447
# meanschooling 447
# educationHDI 447
# compulseduc 447
# GII 447
# DGI 447
# womenparl 447
# hdi 447
# incomeindexHDI 447
# humanineqiality 447
# lifeexpectHDI 447
# homiciderate 447
# Refugeesorigin 447
# internetusers 447
# mobphone 447
# migrationrate 447
# schoolgpi 447
# femchoutsch 447
# choutsch 447
# v2x_polyarchy 447
# v2x_libdem 447
# v2x_partipdem 447
# v2x_delibdem 447
# v2x_egaldem 447
# v2x_freexp_altinf 447
# v2x_frassoc_thick 447
# v2xel_frefair 447
# v2xcl_rol 447
# v2x_cspart 447
# v2xeg_eqdr 447
# v2excrptps 447
# v2exthftps 447
# v2juaccnt 447
# v2cltrnslw 447
# v2clacjust 447
# v2clsocgrp 447
# v2clacfree 447
# v2clrelig 447
# v2csrlgrep 447
# v2mecenefm 447
# v2mecenefi 447
# v2mebias 447
# v2pepwrses 447
# v2pepwrgen 447
# v2peedueq 447
# v2pehealth 447
# v2peapsecon 447
# v2peasjsoecon 447
# v2clgencl 447
# v2peasjgen 447
# v2peasbgen 447
# v2cafres 1447
# v2cafexch 1447
# v2x_corr 447
# v2x_gender 447
# v2x_gencl 447
# v2x_genpp 447
# v2x_rule 447
# v2xcl_acjst 447
# td_voiacc 447
# td_polstab 447
# td_goveff 447
# td_regqual 447
# td_rulelaw 447
# td_ctrlcorr 447
# Partyname 62412

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.preprocessing import LabelEncoder


def feature_selection(df, target_column=None, threshold_corr=0.9, missing_threshold=0.4):
    """
    Универсальная функция для выбора важных признаков в датафрейме.
    
    Параметры:
    df - pandas DataFrame
    target_column - колонка с целевой переменной (если есть)
    threshold_corr - порог корреляции (удаляются сильно коррелирующие признаки)
    missing_threshold - порог удаления признаков с большим количеством пропусков
    
    Возвращает:
    Список оставшихся признаков
    """
    df = df.copy()
    
    # 1. Удаление признаков с большим количеством пропущенных значений
    missing_ratio = df.isnull().sum() / len(df)
    cols_to_drop = missing_ratio[missing_ratio > missing_threshold].index.tolist()
    df.drop(columns=cols_to_drop, inplace=True)
    
    # 2. Удаление признаков с низкой дисперсией
    low_variance_cols = df.var()[df.var() == 0].index.tolist()
    df.drop(columns=low_variance_cols, inplace=True)
    
    # 3. Удаление коррелированных признаков
    corr_matrix = df.corr().abs()
    upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    high_corr_features = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold_corr)]
    df.drop(columns=high_corr_features, inplace=True)
    
    # 4. Выбор наиболее значимых признаков (если есть целевая переменная)
    if target_column and target_column in df.columns:
        X = df.drop(columns=[target_column])
        y = df[target_column]
        
        # Кодирование категориальных признаков
        X = X.apply(lambda col: LabelEncoder().fit_transform(col) if col.dtype == 'object' else col)
        
        if y.dtype == 'object':  # Классификация
            y = LabelEncoder().fit_transform(y)
            importance = mutual_info_classif(X, y)
        else:  # Регрессия
            importance = mutual_info_regression(X, y)
        
        feature_importance = pd.Series(importance, index=X.columns)
        important_features = feature_importance[feature_importance > 0].index.tolist()
        df = df[important_features + [target_column]]
    
    return df

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression

def preprocess_dataframe(df, target_column=None, missing_threshold=0.5, corr_threshold=0.9, pca_components=None, z_threshold=3):
    df = df.copy()
    
    # 1. Удаление столбцов с большим количеством пропущенных значений
    missing_ratio = df.isnull().mean()
    df = df.loc[:, missing_ratio < missing_threshold]
    
    # 2. Удаление признаков с нулевой дисперсией
    df = df.loc[:, df.nunique() > 1]

    # 3. Удаление высоко коррелированных признаков
    numeric_df = df.select_dtypes(include=[np.number])
    corr_matrix = numeric_df.corr().abs()
    upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > corr_threshold)]
    df = df.drop(columns=to_drop, errors="ignore")
    
    # 4. Определение важных признаков (если указан target_column)
    if target_column and target_column in df.columns:
        X = df.drop(columns=[target_column])
        y = df[target_column]
        if y.nunique() > 2:  # Регрессия
            importance = mutual_info_regression(X.fillna(0), y)
        else:  # Классификация
            importance = mutual_info_classif(X.fillna(0), y)
        important_features = X.columns[np.argsort(importance)[-10:]]  # Топ-10
        df = df[[*important_features, target_column]]
    
    # 5. Нормализация данных
    scaler = StandardScaler()
    df[df.select_dtypes(include=[np.number]).columns] = scaler.fit_transform(df.select_dtypes(include=[np.number]))
    
    # 6. PCA (если указано количество компонент)
    if pca_components:
        pca = PCA(n_components=pca_components)
        pca_data = pca.fit_transform(df.select_dtypes(include=[np.number]))
        df = pd.DataFrame(pca_data, columns=[f"PCA_{i+1}" for i in range(pca_components)])
    
    # 7. Удаление выбросов с помощью Z-score
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    z_scores = np.abs((df[numeric_cols] - df[numeric_cols].mean()) / df[numeric_cols].std())
    df = df[(z_scores < z_threshold).all(axis=1)]
    
    return df

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

def preprocess_categorical(df, country_column="B_COUNTRY", fill_missing=True):
    df = df.copy()
    # Обрабатываем категориальные данные
    categorical_cols = df.select_dtypes(include=["object"]).columns
    for col in categorical_cols:
        if col == country_column:
            continue  # Пропускаем столбец со странами, чтобы сохранить их код

        if df[col].nunique() <= 10:  
            # Если <=10 уникальных значений, применяем Label Encoding
            df[col] = LabelEncoder().fit_transform(df[col])
        else:
            # Если больше, применяем частотное кодирование (frequency encoding)
            freq_map = df[col].value_counts(normalize=True).to_dict()
            df[col] = df[col].map(freq_map)

    # Заполняем пропущенные значения
    if fill_missing:
        for col in df.columns:
            if df[col].isnull().sum() > 0:
                if df[col].dtype == "object":
                    df[col].fillna(df[col].mode()[0], inplace=True)  # Заполняем модой
                else:
                    df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой


    # Создаем маппинг страны по коду
    country_mapping = {
        8: "Albania", 20: "Andorra", 32: "Argentina", 51: "Armenia", 36: "Australia",
        40: "Austria", 31: "Azerbaijan", 50: "Bangladesh", 112: "Belarus", 68: "Bolivia",
        70: "Bosnia Herzegovina", 76: "Brazil", 100: "Bulgaria", 124: "Canada", 152: "Chile",
        156: "China", 170: "Colombia", 191: "Croatia", 196: "Cyprus", 203: "Czechia",
        208: "Denmark", 218: "Ecuador", 818: "Egypt", 233: "Estonia", 231: "Ethiopia",
        246: "Finland", 250: "France", 268: "Georgia", 276: "Germany", 826: "Great Britain",
        300: "Greece", 320: "Guatemala", 344: "Hong Kong SAR", 348: "Hungary", 352: "Iceland",
        356: "India", 360: "Indonesia", 364: "Iran", 368: "Iraq", 380: "Italy",
        392: "Japan", 400: "Jordan", 398: "Kazakhstan", 404: "Kenya", 417: "Kyrgyzstan",
        428: "Latvia", 422: "Lebanon", 434: "Libya", 440: "Lithuania", 446: "Macao SAR",
        458: "Malaysia", 462: "Maldives", 484: "Mexico", 496: "Mongolia", 499: "Montenegro",
        504: "Morocco", 104: "Myanmar", 528: "Netherlands", 554: "New Zealand", 558: "Nicaragua",
        566: "Nigeria", 807: "North Macedonia", 909: "Northern Ireland", 578: "Norway",
        586: "Pakistan", 604: "Peru", 608: "Philippines", 616: "Poland", 620: "Portugal",
        630: "Puerto Rico", 642: "Romania", 643: "Russia", 688: "Serbia", 702: "Singapore",
        703: "Slovakia", 705: "Slovenia", 410: "South Korea", 724: "Spain", 752: "Sweden",
        756: "Switzerland", 158: "Taiwan ROC", 762: "Tajikistan", 764: "Thailand", 788: "Tunisia",
        792: "Turkey", 804: "Ukraine", 840: "United States", 858: "Uruguay", 860: "Uzbekistan",
        862: "Venezuela", 704: "Vietnam", 716: "Zimbabwe"
    }
    
    # Добавляем столбец с названием страны
    df["Country_Name"] = df[country_column].map(country_mapping)

    return df

# Использование:
# df_transformed = preprocess_categorical(df)

# %%
# Использование:df
df_numerical = preprocess_categorical(df)
df_feature_selected = feature_selection(df, target_column="target", threshold_corr=0.9, missing_threshold=0.4)
df_cleaned = preprocess_dataframe(df, target_column="target", pca_components=5)
# Out:
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# C:\Users\proje pc 13900k\AppData\Local\Temp\ipykernel_14232\4247172268.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)  # Заполняем медианой
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\nanops.py:1013, in nanvar(values, axis, skipna, ddof, mask)
#    1007 # xref GH10242
#    1008 # Compute variance via two-pass algorithm, which is stable against
#    1009 # cancellation errors and relatively accurate for small numbers of
#    1010 # observations.
#    1011 #
#    1012 # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013 avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014 if axis is not None:
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\numpy\_core\_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# ValueError: could not convert string to float: '6-0-0 (2024-04-30)'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Использование:df
#       2 df_numerical = preprocess_categorical(df)
# ----> 3 df_feature_selected = feature_selection(df, target_column="target", threshold_corr=0.9, missing_threshold=0.4)
#       4 df_cleaned = preprocess_dataframe(df, target_column="target", pca_components=5)
#
# Cell In[13], line 29, in feature_selection(df, target_column, threshold_corr, missing_threshold)
#      26 df.drop(columns=cols_to_drop, inplace=True)
#      28 # 2. Удаление признаков с низкой дисперсией
# ---> 29 low_variance_cols = df.var()[df.var() == 0].index.tolist()
#      30 df.drop(columns=low_variance_cols, inplace=True)
#      32 # 3. Удаление коррелированных признаков
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\frame.py:11734, in DataFrame.var(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11725 @doc(make_doc("var", ndim=2))
#   11726 def var(
#   11727     self,
#    (...)
#   11732     **kwargs,
#   11733 ):
# > 11734     result = super().var(axis, skipna, ddof, numeric_only, **kwargs)
#   11735     if isinstance(result, Series):
#   11736         result = result.__finalize__(self, method="var")
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\generic.py:12346, in NDFrame.var(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12338 def var(
#   12339     self,
#   12340     axis: Axis | None = 0,
#    (...)
#   12344     **kwargs,
#   12345 ) -> Series | float:
# > 12346     return self._stat_function_ddof(
#   12347         "var", nanops.nanvar, axis, skipna, ddof, numeric_only, **kwargs
#   12348     )
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\generic.py:12322, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12319 elif axis is lib.no_default:
#   12320     axis = 0
# > 12322 return self._reduce(
#   12323     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12324 )
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\internals\managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\internals\blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\proje pc 13900k\Sula_temp\ieee-hackaton\venv\Lib\site-packages\pandas\core\nanops.py:92, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
# ---> 92         raise TypeError(e) from e
#      93     raise
#
# TypeError: could not convert string to float: '6-0-0 (2024-04-30)'
